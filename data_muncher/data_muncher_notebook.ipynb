# %%
import pandas as pd

# %%
brute_df = pd.read_csv('data/grafo_oportunidades.csv')
brute_df
# Out:
#     id_business_question                                  business_question  \
# 0                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 1                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 2                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 3                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 4                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 5                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 6                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 7                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 8                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 9                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 10                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 11                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 12                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 13                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 14                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 15                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 16                     1  Quero ter o negócio X (ex: salão de beleza), q...
#
#     id_data_question                                      data_question  \
# 0                  2                    Quais negócios de maior sucesso
# 1                  2                    Quais negócios de maior sucesso
# 2                  2                    Quais negócios de maior sucesso
# 3                  2                    Quais negócios de maior sucesso
# 4                  2                    Quais negócios de maior sucesso
# 5                  2                    Quais negócios de maior sucesso
# 6                  3                   Qual a mortalidade do negócio X?
# 7                  3                   Qual a mortalidade do negócio X?
# 8                  3                   Qual a mortalidade do negócio X?
# 9                  3                   Qual a mortalidade do negócio X?
# 10                 3                   Qual a mortalidade do negócio X?
# 11                 4  Quais locais são similares para se ter o negóc...
# 12                 4  Quais locais são similares para se ter o negóc...
# 13                 4  Quais locais são similares para se ter o negóc...
# 14                 4  Quais locais são similares para se ter o negóc...
# 15                 4  Quais locais são similares para se ter o negóc...
# 16                 4  Quais locais são similares para se ter o negóc...
#
#     id_feature                                         feature  id_dado  \
# 0            5                  Negócios de serviços similares        8
# 1            5                  Negócios de serviços similares        9
# 2            5                  Negócios de serviços similares       10
# 3            5                  Negócios de serviços similares       11
# 4            5                  Negócios de serviços similares       12
# 5            5                  Negócios de serviços similares       13
# 6            6  Tempo de abertura e/ou fechamento das empresas        8
# 7            6  Tempo de abertura e/ou fechamento das empresas        9
# 8            6  Tempo de abertura e/ou fechamento das empresas       10
# 9            6  Tempo de abertura e/ou fechamento das empresas       12
# 10           6  Tempo de abertura e/ou fechamento das empresas       13
# 11           7                 Saturação de negócios similares        8
# 12           7                 Saturação de negócios similares        9
# 13           7                 Saturação de negócios similares       10
# 14           7                 Saturação de negócios similares       11
# 15           7                 Saturação de negócios similares       12
# 16           7                 Saturação de negócios similares       13
#
#                                 dado
# 0   lat/long setor censitário/bairro
# 1                               CNAE
# 2                   Porte da empresa
# 3             Faturamento da empresa
# 4                   Data de abertura
# 5                 Data de fechamento
# 6   lat/long setor censitário/bairro
# 7                               CNAE
# 8                   Porte da empresa
# 9                   Data de abertura
# 10                Data de fechamento
# 11  lat/long setor censitário/bairro
# 12                              CNAE
# 13                  Porte da empresa
# 14            Faturamento da empresa
# 15                  Data de abertura
# 16                Data de fechamento

# %%
brute_df.count()
# Out:
# id_business_question    17
# business_question       17
# id_data_question        17
# data_question           17
# id_feature              17
# feature                 17
# id_dado                 17
# dado                    17
# dtype: int64

# %%
brute_df.sum()
# Out:
# id_business_question                                                   17
# business_question       Quero ter o negócio X (ex: salão de beleza), q...
# id_data_question                                                       34
# data_question           Quais negócios de maior sucessoQuais negócios ...
# id_feature                                                             34
# feature                 Negócios de serviços similaresNegócios de serv...
# id_dado                                                                59
# dado                    lat/long setor censitário/bairroCNAEPorte da e...
# dtype: object

# %%
brute_df[brute_df.dado == 'CNAE'].head()
# Out:
#     id_business_question                                  business_question  \
# 1                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 7                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 12                     1  Quero ter o negócio X (ex: salão de beleza), q...
#
#     id_data_question                                      data_question  \
# 1                  1                    Quais negócios de maior sucesso
# 7                  2                   Qual a mortalidade do negócio X?
# 12                 3  Quais locais são similares para se ter o negóc...
#
#     id_feature                                         feature  id_dado  dado
# 1            1                  Negócios de serviços similares        2  CNAE
# 7            2  Tempo de abertura e/ou fechamento das empresas        2  CNAE
# 12           3                 Saturação de negócios similares        2  CNAE

# %%
import json

def json_create(data):    
    with open('data/result.json', 'w') as fp:
        json.dump(data, fp)

# %% [markdown]
# ## Tratamento

# %%
brute_df.head(20)
# Out:
#     id_business_question                                  business_question  \
# 0                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 1                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 2                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 3                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 4                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 5                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 6                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 7                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 8                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 9                      1  Quero ter o negócio X (ex: salão de beleza), q...
# 10                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 11                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 12                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 13                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 14                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 15                     1  Quero ter o negócio X (ex: salão de beleza), q...
# 16                     1  Quero ter o negócio X (ex: salão de beleza), q...
#
#     id_data_question                                      data_question  \
# 0                  2                    Quais negócios de maior sucesso
# 1                  2                    Quais negócios de maior sucesso
# 2                  2                    Quais negócios de maior sucesso
# 3                  2                    Quais negócios de maior sucesso
# 4                  2                    Quais negócios de maior sucesso
# 5                  2                    Quais negócios de maior sucesso
# 6                  3                   Qual a mortalidade do negócio X?
# 7                  3                   Qual a mortalidade do negócio X?
# 8                  3                   Qual a mortalidade do negócio X?
# 9                  3                   Qual a mortalidade do negócio X?
# 10                 3                   Qual a mortalidade do negócio X?
# 11                 4  Quais locais são similares para se ter o negóc...
# 12                 4  Quais locais são similares para se ter o negóc...
# 13                 4  Quais locais são similares para se ter o negóc...
# 14                 4  Quais locais são similares para se ter o negóc...
# 15                 4  Quais locais são similares para se ter o negóc...
# 16                 4  Quais locais são similares para se ter o negóc...
#
#     id_feature                                         feature  id_dado  \
# 0            5                  Negócios de serviços similares        8
# 1            5                  Negócios de serviços similares        9
# 2            5                  Negócios de serviços similares       10
# 3            5                  Negócios de serviços similares       11
# 4            5                  Negócios de serviços similares       12
# 5            5                  Negócios de serviços similares       13
# 6            6  Tempo de abertura e/ou fechamento das empresas        8
# 7            6  Tempo de abertura e/ou fechamento das empresas        9
# 8            6  Tempo de abertura e/ou fechamento das empresas       10
# 9            6  Tempo de abertura e/ou fechamento das empresas       12
# 10           6  Tempo de abertura e/ou fechamento das empresas       13
# 11           7                 Saturação de negócios similares        8
# 12           7                 Saturação de negócios similares        9
# 13           7                 Saturação de negócios similares       10
# 14           7                 Saturação de negócios similares       11
# 15           7                 Saturação de negócios similares       12
# 16           7                 Saturação de negócios similares       13
#
#                                 dado
# 0   lat/long setor censitário/bairro
# 1                               CNAE
# 2                   Porte da empresa
# 3             Faturamento da empresa
# 4                   Data de abertura
# 5                 Data de fechamento
# 6   lat/long setor censitário/bairro
# 7                               CNAE
# 8                   Porte da empresa
# 9                   Data de abertura
# 10                Data de fechamento
# 11  lat/long setor censitário/bairro
# 12                              CNAE
# 13                  Porte da empresa
# 14            Faturamento da empresa
# 15                  Data de abertura
# 16                Data de fechamento

# %%
# Id dos grupos
number_bq = 1
number_dq = 2
number_feature = 3
number_data = 4

# %%
group_bq = brute_df[['id_business_question', 'business_question']].drop_duplicates()
group_bq['group'] = number_bq
group_bq.rename(columns={'id_business_question': 'id', 'business_question': 'label'}, inplace=True)

# %%
group_bq
# Out:
#    id                                              label  group
# 0   1  Quero ter o negócio X (ex: salão de beleza), q...      1

# %%
group_data_question = brute_df[['id_data_question', 'data_question']].drop_duplicates()
group_data_question['group'] = number_dq
group_data_question.rename(columns={'id_data_question': 'id', 'data_question': 'label'}, inplace=True)

# %%
group_data_question
# Out:
#     id                                              label  group
# 0    2                    Quais negócios de maior sucesso      2
# 6    3                   Qual a mortalidade do negócio X?      2
# 11   4  Quais locais são similares para se ter o negóc...      2

# %%
group_feature = brute_df[['id_feature', 'feature']].drop_duplicates()
group_feature['group'] = number_feature
group_feature.rename(columns={'id_feature': 'id', 'feature': 'label'}, inplace=True)

# %%
group_feature
# Out:
#     id                                           label  group
# 0    5                  Negócios de serviços similares      3
# 6    6  Tempo de abertura e/ou fechamento das empresas      3
# 11   7                 Saturação de negócios similares      3

# %%
group_data = brute_df[['id_dado', 'dado']].drop_duplicates()
group_data['group'] = number_data
group_data.rename(columns={'id_dado': 'id', 'dado': 'label'}, inplace=True)

# %%
group_data
# Out:
#    id                             label  group
# 0   8  lat/long setor censitário/bairro      4
# 1   9                              CNAE      4
# 2  10                  Porte da empresa      4
# 3  11            Faturamento da empresa      4
# 4  12                  Data de abertura      4
# 5  13                Data de fechamento      4

# %%
df_nodes = pd.concat([group_bq, group_data_question, group_feature, group_data], ignore_index=True)

# %%
df_nodes
# Out:
#     id                                              label  group
# 0    1  Quero ter o negócio X (ex: salão de beleza), q...      1
# 1    2                    Quais negócios de maior sucesso      2
# 2    3                   Qual a mortalidade do negócio X?      2
# 3    4  Quais locais são similares para se ter o negóc...      2
# 4    5                     Negócios de serviços similares      3
# 5    6     Tempo de abertura e/ou fechamento das empresas      3
# 6    7                    Saturação de negócios similares      3
# 7    8                   lat/long setor censitário/bairro      4
# 8    9                                               CNAE      4
# 9   10                                   Porte da empresa      4
# 10  11                             Faturamento da empresa      4
# 11  12                                   Data de abertura      4
# 12  13                                 Data de fechamento      4

# %%
from_bq_to_dq = brute_df[['id_business_question', 'id_data_question']].drop_duplicates()

# %%
from_bq_to_dq.rename(columns={'id_business_question': 'from', 'id_data_question': 'to'}, inplace=True)

# %%
from_dq_to_ft = brute_df[['id_data_question', 'id_feature']].drop_duplicates()

# %%
from_dq_to_ft.rename(columns={'id_data_question': 'from', 'id_feature': 'to'}, inplace=True)

# %%
from_ft_to_data = brute_df[['id_feature', 'id_dado']].drop_duplicates()

# %%
from_ft_to_data.rename(columns={'id_feature': 'from', 'id_dado': 'to'}, inplace=True)

# %%
df_edges = pd.concat([from_bq_to_dq, from_dq_to_ft, from_ft_to_data])

# %%
df_edges['from'] = df_edges['from'].astype(int)
df_edges['to'] = df_edges['to'].astype(int)

df_nodes['id'] = df_nodes['id'].astype(int)

# %% [markdown]
# Fiz isso para o pandas se virar convertendo os int64 em int, porque a lib json não consegue converter em json in64

# %%
node_list = df_nodes.to_json(orient='records', force_ascii=False)

# %%
edges_list = df_edges.to_json(orient='records', force_ascii=False)

# %%
result = {'nodes': json.loads(node_list), 'edges': json.loads(edges_list)}

# %%
result
# Out:
# {'nodes': [{'id': 1,
#    'label': 'Quero ter o negócio X (ex: salão de beleza), qual o melhor local para abrir?',
#    'group': 1},
#   {'id': 2, 'label': 'Quais negócios de maior sucesso', 'group': 2},
#   {'id': 3, 'label': 'Qual a mortalidade do negócio X?', 'group': 2},
#   {'id': 4,
#    'label': 'Quais locais são similares para se ter o negócio X?',
#    'group': 2},
#   {'id': 5, 'label': 'Negócios de serviços similares', 'group': 3},
#   {'id': 6,
#    'label': 'Tempo de abertura e/ou fechamento das empresas',
#    'group': 3},
#   {'id': 7, 'label': 'Saturação de negócios similares', 'group': 3},
#   {'id': 8, 'label': 'lat/long setor censitário/bairro', 'group': 4},
#   {'id': 9, 'label': 'CNAE', 'group': 4},
#   {'id': 10, 'label': 'Porte da empresa', 'group': 4},
#   {'id': 11, 'label': 'Faturamento da empresa', 'group': 4},
#   {'id': 12, 'label': 'Data de abertura', 'group': 4},
#   {'id': 13, 'label': 'Data de fechamento', 'group': 4}],
#  'edges': [{'from': 1, 'to': 2},
#   {'from': 1, 'to': 3},
#   {'from': 1, 'to': 4},
#   {'from': 2, 'to': 5},
#   {'from': 3, 'to': 6},
#   {'from': 4, 'to': 7},
#   {'from': 5, 'to': 8},
#   {'from': 5, 'to': 9},
#   {'from': 5, 'to': 10},
#   {'from': 5, 'to': 11},
#   {'from': 5, 'to': 12},
#   {'from': 5, 'to': 13},
#   {'from': 6, 'to': 8},
#   {'from': 6, 'to': 9},
#   {'from': 6, 'to': 10},
#   {'from': 6, 'to': 12},
#   {'from': 6, 'to': 13},
#   {'from': 7, 'to': 8},
#   {'from': 7, 'to': 9},
#   {'from': 7, 'to': 10},
#   {'from': 7, 'to': 11},
#   {'from': 7, 'to': 12},
#   {'from': 7, 'to': 13}]}

# %%
json_create(result)

# %%
result
# Out:
# {'nodes': [{'id': 1,
#    'label': 'Quero ter o negócio X (ex: salão de beleza), qual o melhor local para abrir?',
#    'group': 1},
#   {'id': 2, 'label': 'Quais negócios de maior sucesso', 'group': 2},
#   {'id': 3, 'label': 'Qual a mortalidade do negócio X?', 'group': 2},
#   {'id': 4,
#    'label': 'Quais locais são similares para se ter o negócio X?',
#    'group': 2},
#   {'id': 5, 'label': 'Negócios de serviços similares', 'group': 3},
#   {'id': 6,
#    'label': 'Tempo de abertura e/ou fechamento das empresas',
#    'group': 3},
#   {'id': 7, 'label': 'Saturação de negócios similares', 'group': 3},
#   {'id': 8, 'label': 'lat/long setor censitário/bairro', 'group': 4},
#   {'id': 9, 'label': 'CNAE', 'group': 4},
#   {'id': 10, 'label': 'Porte da empresa', 'group': 4},
#   {'id': 11, 'label': 'Faturamento da empresa', 'group': 4},
#   {'id': 12, 'label': 'Data de abertura', 'group': 4},
#   {'id': 13, 'label': 'Data de fechamento', 'group': 4}],
#  'edges': [{'from': 1, 'to': 2},
#   {'from': 1, 'to': 3},
#   {'from': 1, 'to': 4},
#   {'from': 2, 'to': 5},
#   {'from': 3, 'to': 6},
#   {'from': 4, 'to': 7},
#   {'from': 5, 'to': 8},
#   {'from': 5, 'to': 9},
#   {'from': 5, 'to': 10},
#   {'from': 5, 'to': 11},
#   {'from': 5, 'to': 12},
#   {'from': 5, 'to': 13},
#   {'from': 6, 'to': 8},
#   {'from': 6, 'to': 9},
#   {'from': 6, 'to': 10},
#   {'from': 6, 'to': 12},
#   {'from': 6, 'to': 13},
#   {'from': 7, 'to': 8},
#   {'from': 7, 'to': 9},
#   {'from': 7, 'to': 10},
#   {'from': 7, 'to': 11},
#   {'from': 7, 'to': 12},
#   {'from': 7, 'to': 13}]}
